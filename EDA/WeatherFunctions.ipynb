# %% [markdown]
# # SETUP

# %%
import numpy as np
import itertools
import requests
import datetime
import time
import json
import sys
from datetime import datetime
import pickle
import pandas as pd
import rasterio as rio
import copy
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
from rasterio.transform import Affine
from rasterio.warp import calculate_default_transform, reproject, Resampling

# %%
print("matplotlib",matplotlib.__version__)
print("seaborn",sns.__version__)
print("numpy",np.__version__)
print("pandas",pd.__version__)
print("python",sys.version)

# %% [markdown]
# The Forecast Data API supports HTTP compression. We heartily recommend using it, as it will make responses much smaller over the wire. To enable it, simply add an `Accept-Encoding: gzip` header to your request.

# %% [markdown]
# # Putting it all together: Functions to get weather, create each day's weather from DarkSky json and to upsample each array then store the dictionary of arrays out

# %% [markdown]
# ## Get Weather Data Functions and call

# %%
# Function to get dates of fire in pertinent area from raster file.
def get_fire_dates(yr,path,filename):
    """Get all the dates for a given year that there was fire
    in the raster being studied
    """
    import rasterio as rio
    import numpy as np
    from datetime import datetime
    
    f = path+filename
    # Use the firedata raster to find the day of year 
    with rio.open(f,'r') as rast:
        rastdata = rast.read(1)
    
    # Get unique days of the year there was a pixel on a fireline, as well as counts
    uniq = np.unique(rastdata, return_counts=True)
    days = uniq[0]
    counts = uniq[1]
    
    # Error check that counts are greater than 0
    if np.count_nonzero(counts) > 0:
        days = days[days > 0]  # remove the -9999 no data values

    # Create list of dates for DOY on fireline, date format = ['2016-12-16']
    # time = date+'T12:00:00'
    fire_dates = []
    for day in days:
        s = yr + '-'+ str(day)
        d = datetime.strptime(s,'%Y-%j')
        s2 = str(d.strftime("%Y-%m-%d")) + 'T12:00:00'
        fire_dates.append(s2)
    
    return fire_dates

# %%
def fire_weather(pairs,fire_dates,key):
    """Function to loop through all pairs of lat/long and get the daily weather
    for each point from DarkSky
    Input: list of pairs of lat/long, list of dates, API Key
    Output: Dictionary of list of daily weather jsons
    """
    
    yr_weath = {}
    for date in fire_dates:
        # Call function to get weather for specified date
        data_for_date = getweather(pairs,date,key)
        yr_weath.update({date:data_for_date})
        
    return yr_weath

# %%
def getweather(coordinates,date,key):
    """ Function to take the set of coordinates and get the daily
    weather for a given date. rain, hi and low temps, humidity
    wind speed and direction and cloud cover only.
    
    Called from fire_weather
    
    Input: Date, API Key and list of coordinate pairs (lat,long)
    Output: list of jsons
    """
    import requests
    import json
    
    # items to exclude from call
    blocks = '[currently,minutely,hourly,alerts]'

    # Units for call (km/h, deg C, kPa, mm precip)
    units = 'ca'
    
    # Compression for call
    headers = {'Accept-Encoding':'gzip'}
    
    data_out = []
    for pair in coordinates:
        lat = str(pair[0])
        long = str(pair[1])
        # set the query string for darksky
        query = ('https://api.darksky.net/forecast/'+key+'/'+ 
            lat+','+long+','+date+'?exclude=' 
            +blocks+'&units='+units)
        # Make the call to Dark Sky to get all the data for that date and location
        try:
            r=requests.get(query,headers=headers)
        except requests.exceptions.RequestException as e:
            print(e)
            sys.exit(1)
        
        # get the weather data from the request return
        weather=r.json()
        
        # write the jsons as items in the output data list
        data_out.append(weather)
    
    return data_out

# %%
def setup(path,filename):
    """ one time function to set limits of bounding box for weather
    in lat / long
    Input: raster
    Output: pairs of lat/long, lats and longs    
    """
    import rasterio as rio
    import numpy as np
    
    filestring = path+filename
    with rio.open(filestring) as f:
        left,bottom,right,top = f.bounds
    
    # for rectangle
    bb_long = [left,right,right,left,left]
    bb_lat = [top,top,bottom,bottom,top]
    
    # Create grid of lat/long pairs for retrieving weather data
    min_long = min(bb_long)
    max_long = max(bb_long)
    min_lat = min(bb_lat)
    max_lat = max(bb_lat)

    # 15 x 15 grid
    spaces = 15
    longs = np.linspace(min_long,max_long,spaces)
    lats = np.linspace(min_lat,max_lat,spaces)
    pairs = [(lat,long) for lat in lats for long in longs]
    
    return (pairs,lats,longs)

# %% [markdown]
# ## Change jsons to dataframes and then rasters and reproject before pickling out

# %%
def check_point(info,rain=False):
    """ to check if there is a value for that weather element and provide 
    either None or the value back
    Used in function date_df only
    """
    if info:
        return info
    elif (not info and rain):
        return 0.0        
    else:
        return None

# %%
def date_df(data_out):
    """ Function to take the list of jsons for each lat/long from one date
    of daily weather request and create a pandas dataframe
    
    Input: list of jsons containing the weather data for one day
    Output: pandas dataframe
    """
    data_convert=[]
    # Titles for the data
    coltitles = ['date','latitude','longitude','rainint','raintot','High T','Low T','Humidity','Wind Speed','Wind Direction','Cloud Cover']
    data_convert.append(coltitles)
    # Loope through all the geopoints to get the data
    for point in data_out:
        lat = point['latitude']
        long = point['longitude']
        daily = point.get('daily')
        if daily:
            data = daily['data'][0]
            date = datetime.fromtimestamp(data['time']).strftime('%Y-%m-%d')
            rainint = data.get('precipIntensityMax')
            raintot = data.get('precipAccumulation')
            hitemp = data.get('temperatureHigh')
            lotemp = data.get('temperatureLow')
            humidity = data.get('humidity')
            windspd = data.get('windSpeed')
            winddir = data.get('windBearing')
            clouds = data.get('cloudCover')
            point = [date,lat,long,check_point(rainint,1),check_point(raintot,1), \
                     check_point(hitemp,0),check_point(lotemp,0), \
                     check_point(humidity,0),check_point(windspd,0), \
                     check_point(winddir,0), check_point(clouds,0)] 
            data_convert.append(point)
            
        else:
            point = None
            
    df = pd.DataFrame(data_convert[1:], columns = data_convert[0])
    
    return df

# %%
def jsons_to_arrays(date_jsons,pairs):
    """ Take list of jsons for weather for area being studied (YxY jsons)
    for 1 day and turn them into a dictionary of numpy arrays
    
    Input: list of jsons - 1 per lat/long point and pairs of lat/long
    Output: dictionary of numpy arrays - 1 for each weather type for given date
    """
    
    # Input jsons to pandas dataframe:
    df = date_df(date_jsons)
          
    # Add Missing Rows to dataframe:
    # First get a paired list to determine if any rows are missing
    df['xx'] = list(zip(df['latitude'],df['longitude']))
    missing = pd.DataFrame({'xx':list(set(df['xx']) ^ set(pairs))})
    if not missing.empty:
        missing[['latitude','longitude']]=pd.DataFrame(missing['xx'].tolist(),index=missing.index)
        df = df.append(missing, ignore_index=True, sort=True)
    
    # Sort DataFrame to allow creation of rows in array.
    weather = ['rainint','raintot','High T','Low T','Humidity','Wind Speed','Wind Direction','Cloud Cover']
    weath_sort = df.to_records(index=False)
    weath_sort.sort(order=('latitude','longitude'))

    # Create Dictionary of Numpy Arrays
    weather_date = {}
    for var in weather:
        x = weath_sort[var].reshape(20,20)
        xx = np.flip(x,0)
        weather_date.update({var:xx})
        
    return weather_date

# %%
def new_meta(lats,longs):
    """ Calculate transform and meta data for 20x20 
    raster of lat/long data
    """
    
    # from https://rasterio.readthedocs.io/en/latest/quickstart.html#creating-data
    # See my imported sketches with the correct transforms
    
    #  Resolution
    xres = (longs[-1] - longs[0]) / 19
    yres = (lats[0] - lats[-1]) /19
    
    # affine transform - assumes each lat/long point is in the center of the pixel it represents
    src_transform = Affine.translation(longs[0] - xres / 2, lats[-1] - yres / 2) * Affine.scale(xres, yres)
    
    meta = {'driver':'GTiff','height':20, \
                'width':20,'count':1, \
                'dtype':'float64', 'crs':'+proj=latlong', \
                'transform':src_transform, 'nodata':-9999, \
                'compress':'lzw','interleave':'band'}
    
    return meta

# %%
def reproject_arrs(arrs,path,filename,src_meta):
    """Reproject the lat/long weather arrays to
    raster arrays with new CRS
    
    Input: Dictionary of numpy arrays holding 8 weather variables
    for one date in 20x20 grid based on lat/long, path and filename to raster
    and Source meta data
    Output: Dictionary of numpy arrays holding 8 weather variables
    for one date in grid to match firedata raster.
    """    
    # Get reference meta data from raster
    file = path+filename
    with rio.open(file,'r') as ref:
        refdata = ref.read(1)  # data in raster
        refmeta = ref.meta # meta data in raster
        refres = ref.res # resolution in raster
    
    # Set destination transform and coordinate reference system
    dst_transform = refmeta['transform']
    dst_crs = refmeta['crs']

    # Get source transform and CRS
    src_transform = src_meta['transform']
    src_crs = src_meta['crs']
    
    refmeta['dtype'] = 'float64'
    
    dst_shape = refdata.shape
    destination = np.full(dst_shape, -9999.0)
    
    rp = {}
    for w,a in arrs.items():
        # clear the array before reprojecting each time
        destination = np.full(dst_shape, -9999.0)
        
        reproject(
            a,
            destination,
            src_transform=src_transform,
            src_crs=src_crs,
            dst_transform=dst_transform,
            dst_crs=dst_crs,
            resampling=Resampling.bilinear)
        
        rp.update({str(w):destination})

    return rp

# %% [markdown]
# ## Create reprojected arrays for each date and pickle out

# %%
# Create function to loop over all dates and write out the dictionary
def all_weather(yr_weather,pairs,lats,longs):
    """Loop through all the dates for fire in a year and
    corresponding daily weather jsons (yr_weather), convert
    to numpy arrays and reproject the arrays, then save out the new dictionary
    
    Input: yearly weather from darksky as date keyed dictionary of jsons, with lat/long pairs as pairs and separate lists
    Output: write out the reprojected yearly weather arrays as pickle file
    """
    
    yr_rp_weather = {}    
    for date,data in yr_weather.items():
        # Convert jsons to arrays for given date
        day_data = jsons_to_arrays(data,pairs)  #dictionary of numpy arrays - 1 array for each weather variable keyed by date
        
        # Reproject arrays
        reproj = reproject_arrs(day_data,path,filename,new_meta(lats,longs))
        dt = date[0:10]
        
        yr_rp_weather.update({dt:reproj})
        
    # Pickle out the reprojected array dictionary:
    with open('../data/GlobalFire2016/weather2016data.pickle','wb') as f:
        pickle.dump(yr_rp_weather,f,pickle.HIGHEST_PROTOCOL)
    
    return (len(yr_rp_weather))

# %% [markdown]
# ## Functions to get the weather data for each year from darksky

# %%
def weather(year):
    """Function to run weather functions to get weather data from DarkSky
    for each day in the given year there is a fire in a pixel in the area under question
    """
    import pickle
    
    # Non-Request related setup
    path = '../data/GlobalFire/'+year+'/'
    filename = 'BBfirelineCA.tif'  # use fireline to get all pixels involved in a fire in that year

    # Get pairs of lats and longs
    pairs,lats,longs = setup(path,filename)

    # Get dates for required request
    fire_dates = get_fire_dates(year,path,filename)

    # Dark Sky API key (Laura Chutny)
    key = '5ffac5f056d341c6296cba58fa96e9ba'
    # Make requests to DarkSky
    yr_weather = fire_weather(pairs,fire_dates,key)  # Dictionary of jsons

    # Pickle out the jsons to avoid another call to API (just in case something goes wrong)
    weathfile = path+'weatherjsons.pickle'
    with open(weathfile,'wb') as f:
        pickle.dump(yr_weather,f,pickle.HIGHEST_PROTOCOL)
    print(f"{weathfile} printed for year {year}")

#     weather_days = all_weather(yr_weather,pairs,lats,longs)
#     print(f"Number of days of weather reprojected for {year}:{weather_days}")
    
    return fire_dates

# %%
# %%time
#years = ['2003']
years = ['2004','2005','2006','2007']
#years = ['2008','2009','2010','2011']
#years = ['2012','2013','2014','2015','2016']
fire_dates={}
fire_date_nums={}
for year in years:
    fds = weather(year)
    fire_dates[year]=fds
    fire_date_nums[year]=len(fds)
# Out:
# ../data/GlobalFire/2003/weatherjsons.pickle printed for year 2003
# Wall time: 3h 19min 27s

# %%
# Check number of API calls
num_points_day = 15*15  #20x20 matrix of lat long
# count total days:
totaldays = 0
for year in fire_date_nums:
    totaldays += fire_date_nums[year]
print(totaldays)
total_calls=totaldays*num_points_day
print(total_calls)
cost_percall = 0.0001
totalcost = total_calls*cost_percall
print(f"${totalcost:.2f}")
# Out:
# 179
# 40275
# $4.03

# %%
len(pairs)
# Out:
# 400

# %% [markdown]
# ## Function to reproject and save weather Jsons

# %%
reproject the data and save out as a pickled numpy array.
FIX pickle out file name

# %%
# %%time
#years = ['2003','2004','2005','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016',]
years = ['2016']
weather(years)

# %% [markdown]
# # Check if data correctly reprojected

# %%
def plot_weather(day_weath):
    """ Plot all the weather components for that day"""
    fig = plt.figure(figsize = (20,8))
    fig.subplots_adjust(hspace=0.4,wspace=0.4)
    i=1
    for key,data in day_weath.items():
        ax = fig.add_subplot(2,4,i)
        sns.heatmap(data)
        ax.set_title(key)
        i+=1
    plt.show()

# %%
x1 = y1[0]
plot_weather(x1)

# %%
for year in years:
    #path = '../data/GlobalFire/'+year+'/'   
    #filename = 'weather'+year+'data.pickle'
    #filestring = path+filename
    filestring='../data/GlobalFire2016/weather2016data.pickle'
    with open(filestring,'rb') as f:
        y1 = pickle.load(f)
    x1 = y[1] #arbitrary day
    print(f"Year{year}")
    plot_weather(x1)

# %% [markdown]
# # Extra Code

# %%
# Return from pickle for further work
import pickle
with open('../data/GlobalFire/2003/weatherjsons.pickle','rb') as f:
    z = pickle.load(f)

# %%
z.keys()
# Out:
# dict_keys(['2003-01-10T12:00:00', '2003-01-11T12:00:00', '2003-01-12T12:00:00', '2003-01-13T12:00:00', '2003-01-14T12:00:00', '2003-01-15T12:00:00', '2003-01-16T12:00:00', '2003-01-17T12:00:00', '2003-02-25T12:00:00', '2003-02-26T12:00:00', '2003-02-27T12:00:00', '2003-02-28T12:00:00', '2003-03-01T12:00:00', '2003-03-02T12:00:00', '2003-03-03T12:00:00', '2003-03-04T12:00:00', '2003-03-05T12:00:00', '2003-03-06T12:00:00', '2003-03-07T12:00:00', '2003-03-08T12:00:00', '2003-03-09T12:00:00', '2003-03-10T12:00:00', '2003-03-11T12:00:00', '2003-03-12T12:00:00', '2003-03-14T12:00:00', '2003-03-15T12:00:00', '2003-03-16T12:00:00', '2003-03-17T12:00:00', '2003-03-18T12:00:00', '2003-03-19T12:00:00', '2003-03-20T12:00:00', '2003-03-21T12:00:00', '2003-03-22T12:00:00', '2003-03-23T12:00:00', '2003-03-25T12:00:00', '2003-03-30T12:00:00', '2003-05-02T12:00:00', '2003-05-03T12:00:00', '2003-05-04T12:00:00', '2003-05-05T12:00:00', '2003-05-06T12:00:00', '2003-05-07T12:00:00', '2003-05-08T12:00:00', '2003-05-09T12:00:00', '2003-05-10T12:00:00', '2003-05-11T12:00:00', '2003-05-18T12:00:00', '2003-05-19T12:00:00', '2003-05-20T12:00:00', '2003-05-21T12:00:00', '2003-05-22T12:00:00', '2003-05-26T12:00:00', '2003-05-29T12:00:00', '2003-05-30T12:00:00', '2003-05-31T12:00:00', '2003-06-01T12:00:00', '2003-06-02T12:00:00', '2003-06-03T12:00:00', '2003-06-04T12:00:00', '2003-06-05T12:00:00', '2003-06-07T12:00:00', '2003-06-08T12:00:00', '2003-06-15T12:00:00', '2003-06-16T12:00:00', '2003-06-17T12:00:00', '2003-06-18T12:00:00', '2003-06-19T12:00:00', '2003-06-20T12:00:00', '2003-06-21T12:00:00', '2003-07-03T12:00:00', '2003-07-09T12:00:00', '2003-07-16T12:00:00', '2003-07-19T12:00:00', '2003-07-20T12:00:00', '2003-07-21T12:00:00', '2003-07-22T12:00:00', '2003-07-23T12:00:00', '2003-07-24T12:00:00', '2003-07-31T12:00:00', '2003-08-01T12:00:00', '2003-08-02T12:00:00', '2003-08-03T12:00:00', '2003-08-04T12:00:00', '2003-08-05T12:00:00', '2003-08-06T12:00:00', '2003-08-07T12:00:00', '2003-08-08T12:00:00', '2003-08-09T12:00:00', '2003-08-10T12:00:00', '2003-08-11T12:00:00', '2003-08-12T12:00:00', '2003-08-13T12:00:00', '2003-08-15T12:00:00', '2003-08-16T12:00:00', '2003-08-21T12:00:00', '2003-08-22T12:00:00', '2003-08-23T12:00:00', '2003-08-24T12:00:00', '2003-08-25T12:00:00', '2003-08-26T12:00:00', '2003-08-27T12:00:00', '2003-08-28T12:00:00', '2003-08-29T12:00:00', '2003-08-30T12:00:00', '2003-08-31T12:00:00', '2003-09-01T12:00:00', '2003-09-02T12:00:00', '2003-09-03T12:00:00', '2003-09-04T12:00:00', '2003-09-05T12:00:00', '2003-09-06T12:00:00', '2003-09-07T12:00:00', '2003-09-08T12:00:00', '2003-09-09T12:00:00', '2003-09-11T12:00:00', '2003-09-12T12:00:00', '2003-09-13T12:00:00', '2003-09-14T12:00:00', '2003-09-15T12:00:00', '2003-09-16T12:00:00', '2003-09-17T12:00:00', '2003-09-18T12:00:00', '2003-09-19T12:00:00', '2003-09-20T12:00:00', '2003-09-21T12:00:00', '2003-09-22T12:00:00', '2003-09-23T12:00:00', '2003-09-24T12:00:00', '2003-09-25T12:00:00', '2003-09-26T12:00:00', '2003-09-27T12:00:00', '2003-09-28T12:00:00', '2003-09-29T12:00:00', '2003-09-30T12:00:00', '2003-10-01T12:00:00', '2003-10-03T12:00:00', '2003-10-05T12:00:00', '2003-10-06T12:00:00', '2003-10-07T12:00:00', '2003-10-08T12:00:00', '2003-10-09T12:00:00', '2003-10-10T12:00:00', '2003-10-13T12:00:00', '2003-10-14T12:00:00', '2003-10-15T12:00:00', '2003-10-16T12:00:00', '2003-10-21T12:00:00', '2003-10-22T12:00:00', '2003-10-23T12:00:00', '2003-10-24T12:00:00', '2003-10-25T12:00:00', '2003-10-26T12:00:00', '2003-11-04T12:00:00', '2003-11-05T12:00:00', '2003-11-06T12:00:00', '2003-11-07T12:00:00', '2003-11-08T12:00:00', '2003-11-10T12:00:00', '2003-11-11T12:00:00', '2003-11-12T12:00:00', '2003-11-13T12:00:00', '2003-11-14T12:00:00', '2003-11-15T12:00:00', '2003-11-16T12:00:00', '2003-11-17T12:00:00', '2003-11-18T12:00:00', '2003-11-19T12:00:00', '2003-11-20T12:00:00', '2003-11-21T12:00:00', '2003-11-22T12:00:00', '2003-11-23T12:00:00', '2003-11-24T12:00:00', '2003-11-25T12:00:00', '2003-11-2 ...

# %%
len(z)
# Out:
# 179

# %%
z['2003-01-10T12:00:00']
# Out:
# [{'latitude': 35.998562135684054,
#   'longitude': -123.50294421461426,
#   'timezone': 'America/Los_Angeles',
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 35.998562135684054,
#   'longitude': -123.21681063271468,
#   'timezone': 'America/Los_Angeles',
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 35.998562135684054,
#   'longitude': -122.9306770508151,
#   'timezone': 'America/Los_Angeles',
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 95.146,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 35.998562135684054,
#   'longitude': -122.64454346891553,
#   'timezone': 'America/Los_Angeles',
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 73.939,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 35.998562135684054,
#   'longitude': -122.35840988701595,
#   'timezone': 'America/Los_Angeles',
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 51.114,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 35.998562135684054,
#   'longitude': -122.07227630511638,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'sunriseTime': 1042212000,
#      'sunsetTime': 1042247640,
#      'moonPhase': 0.27,
#      'temperatureHigh': 15.27,
#      'temperatureHighTime': 1042232520,
#      'temperatureLow': 11.23,
#      'temperatureLowTime': 1042300800,
#      'apparentTemperatureHigh': 14.99,
#      'apparentTemperatureHighTime': 1042232520,
#      'apparentTemperatureLow': 11.5,
#      'apparentTemperatureLowTime': 1042300800,
#      'dewPoint': 12.09,
#      'humidity': 0.88,
#      'pressure': 1018.6,
#      'windSpeed': 10.57,
#      'windGust': 23.16,
#      'windGustTime': 1042187700,
#      'windBearing': 163,
#      'uvIndex': 0,
#      'uvIndexTime': 1042185600,
#      'temperatureMin': 12.69,
#      'temperatureMinTime': 1042268400,
#      'temperatureMax': 15.27,
#      'temperatureMaxTime': 1042232520,
#      'apparentTemperatureMin': 12.96,
#      'apparentTemperatureMinTime': 1042268400,
#      'apparentTemperatureMax': 14.99,
#      'apparentTemperatureMaxTime': 1042232520}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 33.076,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 35.998562135684054,
#   'longitude': -121.7861427232168,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'sunriseTime': 1042211940,
#      'sunsetTime': 1042247520,
#      'moonPhase': 0.27,
#      'temperatureHigh': 16.06,
#      'temperatureHighTime': 1042233060,
#      'temperatureLow': 10.44,
#      'temperatureLowTime': 1042297260,
#      'apparentTemperatureHigh': 15.78,
#      'apparentTemperatureHighTime': 1042233060,
#      'apparentTemperatureLow': 10.71,
#      'apparentTemperatureLowTime': 1042297260,
#      'dewPoint': 11.06,
#      'humidity': 0.83,
#      'pressure': 1018.6,
#      'windSpeed': 7.83,
#      'windGust': 16.22,
#      'windGustTime': 1042233600,
#      'windBearing': 161,
#      'uvIndex': 0,
#      'uvIndexTime': 1042185600,
#      'temperatureMin': 11.88,
#      'temperatureMinTime': 1042268400,
#      'temperatureMax': 16.06,
#      'temperatureMaxTime': 1042233060,
#      'apparentTemperatureMin': 12.15,
#      'apparentTemperatureMinTime': 1042268400,
#      'apparentTemperatureMax': 15.78,
#      'apparentTemperatureMaxTime': 1042233060}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 18.707,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 35.998562135684054,
#   'longitude': -121.50000914131724,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'summary': 'Rain in the morning and afternoon.',
#      'icon': 'rain',
#      'sunriseTime': 1042211880,
#      'sunsetTime': 1042247460,
#      'moonPhase': 0.27,
#      'precipIntensity': 0.6931,
#      'precipIntensityMax': 3.1076,
#      'precipIntensityMaxTime': 1042211280,
#      'precipProbability': 1,
#      'precipType': 'rain',
#      'temperatureHigh': 14.96,
#      'temperatureHighTime': 1042242360,
#      'temperatureLow': 7.23,
#      'temperatureLowTime': 1042297140,
#      'apparentTemperatureHigh': 14.68,
#      'apparentTemperatureHighTime': 1042242360,
#      'apparentTemperatureLow': 7.5,
#      'apparentTemperatureLowTime': 1042297140,
#      'dewPoint': 10.38,
#      'humidity': 0.9,
#      'pressure': 1018.8,
#      'windSpeed': 8.3,
#      'windGust': 14.22,
#      'windGustTime': 1042233840,
#      'windBearing': 150,
#      'uvIndex': 0,
#      'uvIndexTime': 1042185600,
#      'temperatureMin': 9.33,
#      'temperatureMinTime': 1042268400,
#      'temperatureMax': 14.96,
#      'temperatureMaxTime': 1042242360,
#      'apparentTemperatureMin': 9.6,
#      'apparentTemperatureMinTime': 1042268400,
#      'apparentTemperatureMax': 14.68,
#      'apparentTemperatureMaxTime': 1042242360}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 9.324,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 35.998562135684054,
#   'longitude': -121.21387555941766,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'summary': 'Rain in the morning and afternoon.',
#      'icon': 'rain',
#      'sunriseTime': 1042211820,
#      'sunsetTime': 1042247400,
#      'moonPhase': 0.27,
#      'precipIntensity': 0.6931,
#      'precipIntensityMax': 3.1076,
#      'precipIntensityMaxTime': 1042211280,
#      'precipProbability': 1,
#      'precipType': 'rain',
#      'temperatureHigh': 16.31,
#      'temperatureHighTime': 1042242780,
#      'temperatureLow': 2.51,
#      'temperatureLowTime': 1042297200,
#      'apparentTemperatureHigh': 16.03,
#      'apparentTemperatureHighTime': 1042242780,
#      'apparentTemperatureLow': 2.78,
#      'apparentTemperatureLowTime': 1042297200,
#      'dewPoint': 9.01,
#      'humidity': 0.88,
#      'pressure': 1019,
#      'windSpeed': 7.31,
#      'windGust': 14.54,
#      'windGustTime': 1042207020,
#      'windBearing': 131,
#      'uvIndex': 0,
#      'uvIndexTime': 1042185600,
#      'temperatureMin': 6.23,
#      'temperatureMinTime': 1042268400,
#      'temperatureMax': 16.31,
#      'temperatureMaxTime': 1042242780,
#      'apparentTemperatureMin': 6.5,
#      'apparentTemperatureMinTime': 1042268400,
#      'apparentTemperatureMax': 16.03,
#      'apparentTemperatureMaxTime': 1042242780}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 2.901,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 35.998562135684054,
#   'longitude': -120.92774197751808,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'summary': 'Light rain until evening.',
#      'icon': 'rain',
#      'sunriseTime': 1042211760,
#      'sunsetTime': 1042247340,
#      'moonPhase': 0.27,
#      'precipIntensity': 0.337,
#      'precipIntensityMax': 1.4342,
#      'precipIntensityMaxTime': 1042211280,
#      'precipProbability': 1,
#      'precipType': 'rain',
#      'temperatureHigh': 14.99,
#      'temperatureHighTime': 1042244400,
#      'temperatureLow': 7.3,
#      'temperatureLowTime': 1042297500,
#      'apparentTemperatureHigh': 14.71,
#      'apparentTemperatureHighTime': 1042244400,
#      'apparentTemperatureLow': 7.57,
#      'apparentTemperatureLowTime': 1042297500,
#      'dewPoint': 9.51,
#      'humidity': 0.84,
#      'pressure': 1018.8,
#      'windSpeed': 9.2,
#      'windGust': 22.36,
#      'windGustTime': 1042193520,
#      'windBearing': 143,
#      'cloudCover': 0.74,
#      'uvIndex': 2,
#      'uvIndexTime': 1042229460,
#      'visibility': 15.055,
#      'temperatureMin': 8.3,
#      'temperatureMinTime': 1042268400,
#      'temperatureMax': 14.99,
#      'temperatureMaxTime': 1042244400,
#      'apparentTemperatureMin': 8.57,
#      'apparentTemperatureMinTime': 1042268400,
#      'apparentTemperatureMax': 14.71,
#      'apparentTemperatureMaxTime': 1042244400}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 8.529,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 35.998562135684054,
#   'longitude': -120.6416083956185,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'summary': 'Light rain until evening.',
#      'icon': 'rain',
#      'sunriseTime': 1042211700,
#      'sunsetTime': 1042247280,
#      'moonPhase': 0.27,
#      'precipIntensity': 0.0851,
#      'precipIntensityMax': 0.8903,
#      'precipIntensityMaxTime': 1042225200,
#      'precipProbability': 1,
#      'precipType': 'rain',
#      'temperatureHigh': 13.62,
#      'temperatureHighTime': 1042246020,
#      'temperatureLow': 6,
#      'temperatureLowTime': 1042269360,
#      'apparentTemperatureHigh': 13.34,
#      'apparentTemperatureHighTime': 1042246020,
#      'apparentTemperatureLow': 5.52,
#      'apparentTemperatureLowTime': 1042297260,
#      'dewPoint': 9.15,
#      'humidity': 0.91,
#      'pressure': 1018.6,
#      'windSpeed': 7.63,
#      'windGust': 26.23,
#      'windGustTime': 1042232340,
#      'windBearing': 156,
#      'cloudCover': 0.74,
#      'uvIndex': 2,
#      'uvIndexTime': 1042229340,
#      'visibility': 15.055,
#      'temperatureMin': 6.05,
#      'temperatureMinTime': 1042268400,
#      'temperatureMax': 13.62,
#      'temperatureMaxTime': 1042246020,
#      'apparentTemperatureMin': 6.32,
#      'apparentTemperatureMinTime': 1042268400,
#      'apparentTemperatureMax': 13.34,
#      'apparentTemperatureMaxTime': 1042246020}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 3.124,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 35.998562135684054,
#   'longitude': -120.35547481371893,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'summary': 'Light rain until evening.',
#      'icon': 'rain',
#      'sunriseTime': 1042211580,
#      'sunsetTime': 1042247220,
#      'moonPhase': 0.27,
#      'precipIntensity': 0.0851,
#      'precipIntensityMax': 0.8903,
#      'precipIntensityMaxTime': 1042225200,
#      'precipProbability': 1,
#      'precipType': 'rain',
#      'temperatureHigh': 13.1,
#      'temperatureHighTime': 1042239960,
#      'temperatureLow': 4.7,
#      'temperatureLowTime': 1042268580,
#      'apparentTemperatureHigh': 12.82,
#      'apparentTemperatureHighTime': 1042239960,
#      'apparentTemperatureLow': 4.97,
#      'apparentTemperatureLowTime': 1042268580,
#      'dewPoint': 8.67,
#      'humidity': 0.96,
#      'pressure': 1018.6,
#      'windSpeed': 6.19,
#      'windGust': 28.26,
#      'windGustTime': 1042232460,
#      'windBearing': 161,
#      'cloudCover': 0.74,
#      'uvIndex': 2,
#      'uvIndexTime': 1042229280,
#      'visibility': 15.055,
#      'temperatureMin': 4.7,
#      'temperatureMinTime': 1042268400,
#      'temperatureMax': 13.1,
#      'temperatureMaxTime': 1042239960,
#      'apparentTemperatureMin': 4.97,
#      'apparentTemperatureMinTime': 1042268400,
#      'apparentTemperatureMax': 12.82,
#      'apparentTemperatureMaxTime': 1042239960}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 8.247,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 35.998562135684054,
#   'longitude': -120.06934123181935,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'sunriseTime': 1042211520,
#      'sunsetTime': 1042247160,
#      'moonPhase': 0.27,
#      'precipType': 'rain',
#      'temperatureHigh': 12.71,
#      'temperatureHighTime': 1042239660,
#      'apparentTemperatureHigh': 12.43,
#      'apparentTemperatureHighTime': 1042239660,
#      'dewPoint': 9.99,
#      'humidity': 0.9,
#      'pressure': 1019.7,
#      'windSpeed': 13.56,
#      'windGust': 46.13,
#      'windGustTime': 1042234200,
#      'windBearing': 156,
#      'cloudCover': 0.81,
#      'uvIndex': 2,
#      'uvIndexTime': 1042229400,
#      'visibility': 5.403,
#      'temperatureMin': 7.05,
#      'temperatureMinTime': 1042264800,
#      'temperatureMax': 13.2,
#      'temperatureMaxTime': 1042193100,
#      'apparentTemperatureMin': 6.3,
#      'apparentTemperatureMinTime': 1042264800,
#      'apparentTemperatureMax': 12.92,
#      'apparentTemperatureMaxTime': 1042193100}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 3.844,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 35.998562135684054,
#   'longitude': -119.78320764991977,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'sunriseTime': 1042211460,
#      'sunsetTime': 1042247040,
#      'moonPhase': 0.27,
#      'precipType': 'rain',
#      'temperatureHigh': 14.56,
#      'temperatureHighTime': 1042241580,
#      'temperatureLow': 4.81,
#      'temperatureLowTime': 1042293420,
#      'apparentTemperatureHigh': 14.28,
#      'apparentTemperatureHighTime': 1042241580,
#      'apparentTemperatureLow': 4.49,
#      'apparentTemperatureLowTime': 1042300440,
#      'dewPoint': 10.18,
#      'humidity': 0.87,
#      'pressure': 1019.5,
#      'windSpeed': 9.95,
#      'windGust': 46.65,
#      'windGustTime': 1042234320,
#      'windBearing': 144,
#      'cloudCover': 0.73,
#      'uvIndex': 2,
#      'uvIndexTime': 1042229820,
#      'visibility': 6.874,
#      'temperatureMin': 7.94,
#      'temperatureMinTime': 1042268400,
#      'temperatureMax': 14.56,
#      'temperatureMaxTime': 1042241580,
#      'apparentTemperatureMin': 7.9,
#      'apparentTemperatureMinTime': 1042265700,
#      'apparentTemperatureMax': 14.28,
#      'apparentTemperatureMaxTime': 1042241580}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 18.653,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 35.998562135684054,
#   'longitude': -119.4970740680202,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'sunriseTime': 1042211400,
#      'sunsetTime': 1042246980,
#      'moonPhase': 0.27,
#      'precipIntensity': 0.4898,
#      'precipIntensityMax': 1.0181,
#      'precipIntensityMaxTime': 1042224840,
#      'precipType': 'rain',
#      'temperatureHigh': 14.62,
#      'temperatureHighTime': 1042242780,
#      'temperatureLow': 4.6,
#      'temperatureLowTime': 1042299720,
#      'apparentTemperatureHigh': 14.34,
#      'apparentTemperatureHighTime': 1042242780,
#      'apparentTemperatureLow': 4.39,
#      'apparentTemperatureLowTime': 1042290360,
#      'dewPoint': 9.57,
#      'humidity': 0.9,
#      'pressure': 1019.6,
#      'windSpeed': 4.87,
#      'windBearing': 93,
#      'cloudCover': 0.59,
#      'uvIndex': 2,
#      'uvIndexTime': 1042230420,
#      'visibility': 9.486,
#      'temperatureMin': 7.83,
#      'temperatureMinTime': 1042268400,
#      'temperatureMax': 14.62,
#      'temperatureMaxTime': 1042242780,
#      'apparentTemperatureMin': 8.1,
#      'apparentTemperatureMinTime': 1042268400,
#      'apparentTemperatureMax': 14.34,
#      'apparentTemperatureMaxTime': 1042242780}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 18.272,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 36.21302673657214,
#   'longitude': -123.50294421461426,
#   'timezone': 'America/Los_Angeles',
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 36.21302673657214,
#   'longitude': -123.21681063271468,
#   'timezone': 'America/Los_Angeles',
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 93.001,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 36.21302673657214,
#   'longitude': -122.9306770508151,
#   'timezone': 'America/Los_Angeles',
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 75.132,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 36.21302673657214,
#   'longitude': -122.64454346891553,
#   'timezone': 'America/Los_Angeles',
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 62.891,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 36.21302673657214,
#   'longitude': -122.35840988701595,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'sunriseTime': 1042212120,
#      'sunsetTime': 1042247640,
#      'moonPhase': 0.27,
#      'temperatureHigh': 15.56,
#      'temperatureHighTime': 1042236000,
#      'temperatureLow': 10.39,
#      'temperatureLowTime': 1042299720,
#      'apparentTemperatureHigh': 15.28,
#      'apparentTemperatureHighTime': 1042236000,
#      'apparentTemperatureLow': 10.66,
#      'apparentTemperatureLowTime': 1042299720,
#      'dewPoint': 12.71,
#      'humidity': 0.93,
#      'windSpeed': 8.29,
#      'windBearing': 130,
#      'uvIndex': 0,
#      'uvIndexTime': 1042185600,
#      'temperatureMin': 12.1,
#      'temperatureMinTime': 1042265160,
#      'temperatureMax': 15.56,
#      'temperatureMaxTime': 1042236000,
#      'apparentTemperatureMin': 12.37,
#      'apparentTemperatureMinTime': 1042265160,
#      'apparentTemperatureMax': 15.28,
#      'apparentTemperatureMaxTime': 1042236000}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 41.956,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 36.21302673657214,
#   'longitude': -122.07227630511638,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'icon': 'rain',
#      'sunriseTime': 1042212060,
#      'sunsetTime': 1042247580,
#      'moonPhase': 0.27,
#      'precipIntensity': 0.8685,
#      'precipIntensityMax': 2.6053,
#      'precipIntensityMaxTime': 1042203720,
#      'precipProbability': 1,
#      'precipType': 'rain',
#      'temperatureHigh': 16.57,
#      'temperatureHighTime': 1042236120,
#      'temperatureLow': 10.38,
#      'temperatureLowTime': 1042300200,
#      'apparentTemperatureHigh': 16.29,
#      'apparentTemperatureHighTime': 1042236120,
#      'apparentTemperatureLow': 10.65,
#      'apparentTemperatureLowTime': 1042300200,
#      'dewPoint': 12.07,
#      'humidity': 0.88,
#      'pressure': 1019,
#      'windSpeed': 6.1,
#      'windGust': 23.16,
#      'windGustTime': 1042187700,
#      'windBearing': 143,
#      'cloudCover': 0.75,
#      'uvIndex': 2,
#      'uvIndexTime': 1042231860,
#      'visibility': 14.038,
#      'temperatureMin': 11.74,
#      'temperatureMinTime': 1042268400,
#      'temperatureMax': 16.57,
#      'temperatureMaxTime': 1042236120,
#      'apparentTemperatureMin': 12.01,
#      'apparentTemperatureMinTime': 1042268400,
#      'apparentTemperatureMax': 16.29,
#      'apparentTemperatureMaxTime': 1042236120}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 18.499,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 36.21302673657214,
#   'longitude': -121.7861427232168,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'icon': 'rain',
#      'sunriseTime': 1042212000,
#      'sunsetTime': 1042247520,
#      'moonPhase': 0.27,
#      'precipIntensity': 0.8727,
#      'precipIntensityMax': 2.6234,
#      'precipIntensityMaxTime': 1042203720,
#      'precipProbability': 1,
#      'precipType': 'rain',
#      'temperatureHigh': 17.19,
#      'temperatureHighTime': 1042236000,
#      'temperatureLow': 10.09,
#      'temperatureLowTime': 1042283340,
#      'apparentTemperatureHigh': 16.91,
#      'apparentTemperatureHighTime': 1042236000,
#      'apparentTemperatureLow': 10.36,
#      'apparentTemperatureLowTime': 1042283340,
#      'dewPoint': 11.61,
#      'humidity': 0.84,
#      'pressure': 1019,
#      'windSpeed': 2.45,
#      'windGust': 22.71,
#      'windGustTime': 1042187640,
#      'windBearing': 149,
#      'cloudCover': 0.75,
#      'uvIndex': 2,
#      'uvIndexTime': 1042231860,
#      'visibility': 14.038,
#      'temperatureMin': 11.71,
#      'temperatureMinTime': 1042268400,
#      'temperatureMax': 17.19,
#      'temperatureMaxTime': 1042236000,
#      'apparentTemperatureMin': 11.98,
#      'apparentTemperatureMinTime': 1042268400,
#      'apparentTemperatureMax': 16.91,
#      'apparentTemperatureMaxTime': 1042236000}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 2.503,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 36.21302673657214,
#   'longitude': -121.50000914131724,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'sunriseTime': 1042211940,
#      'sunsetTime': 1042247460,
#      'moonPhase': 0.27,
#      'temperatureHigh': 16.68,
#      'temperatureHighTime': 1042232760,
#      'temperatureLow': 5.05,
#      'temperatureLowTime': 1042287480,
#      'apparentTemperatureHigh': 16.4,
#      'apparentTemperatureHighTime': 1042232760,
#      'apparentTemperatureLow': 5.32,
#      'apparentTemperatureLowTime': 1042287480,
#      'dewPoint': 9.57,
#      'humidity': 0.93,
#      'windSpeed': 0.9,
#      'windGust': 24.8,
#      'windGustTime': 1042233540,
#      'windBearing': 218,
#      'uvIndex': 0,
#      'uvIndexTime': 1042185600,
#      'temperatureMin': 7.33,
#      'temperatureMinTime': 1042268400,
#      'temperatureMax': 16.68,
#      'temperatureMaxTime': 1042232760,
#      'apparentTemperatureMin': 7.6,
#      'apparentTemperatureMinTime': 1042268400,
#      'apparentTemperatureMax': 16.4,
#      'apparentTemperatureMaxTime': 1042232760}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 2.026,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 36.21302673657214,
#   'longitude': -121.21387555941766,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'sunriseTime': 1042211820,
#      'sunsetTime': 1042247400,
#      'moonPhase': 0.27,
#      'temperatureHigh': 16.22,
#      'temperatureHighTime': 1042242780,
#      'temperatureLow': 5.55,
#      'temperatureLowTime': 1042297260,
#      'apparentTemperatureHigh': 15.94,
#      'apparentTemperatureHighTime': 1042242780,
#      'apparentTemperatureLow': 5.82,
#      'apparentTemperatureLowTime': 1042297260,
#      'dewPoint': 9.01,
#      'humidity': 0.84,
#      'windSpeed': 6.13,
#      'windGust': 17.77,
#      'windGustTime': 1042210980,
#      'windBearing': 154,
#      'uvIndex': 0,
#      'uvIndexTime': 1042185600,
#      'temperatureMin': 8.59,
#      'temperatureMinTime': 1042268400,
#      'temperatureMax': 16.22,
#      'temperatureMaxTime': 1042242780,
#      'apparentTemperatureMin': 8.86,
#      'apparentTemperatureMinTime': 1042268400,
#      'apparentTemperatureMax': 15.94,
#      'apparentTemperatureMaxTime': 1042242780}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 4.034,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 36.21302673657214,
#   'longitude': -120.92774197751808,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'sunriseTime': 1042211760,
#      'sunsetTime': 1042247280,
#      'moonPhase': 0.27,
#      'temperatureHigh': 13.15,
#      'temperatureHighTime': 1042243740,
#      'temperatureLow': 6.98,
#      'temperatureLowTime': 1042297680,
#      'apparentTemperatureHigh': 12.87,
#      'apparentTemperatureHighTime': 1042243740,
#      'apparentTemperatureLow': 6.07,
#      'apparentTemperatureLowTime': 1042297320,
#      'dewPoint': 7.37,
#      'humidity': 0.81,
#      'windSpeed': 13.67,
#      'windGust': 42.79,
#      'windGustTime': 1042210920,
#      'windBearing': 183,
#      'uvIndex': 0,
#      'uvIndexTime': 1042185600,
#      'temperatureMin': 8.24,
#      'temperatureMinTime': 1042268400,
#      'temperatureMax': 13.15,
#      'temperatureMaxTime': 1042243740,
#      'apparentTemperatureMin': 6.93,
#      'apparentTemperatureMinTime': 1042195260,
#      'apparentTemperatureMax': 12.87,
#      'apparentTemperatureMaxTime': 1042243740}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 14.975,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 36.21302673657214,
#   'longitude': -120.6416083956185,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'sunriseTime': 1042211700,
#      'sunsetTime': 1042247220,
#      'moonPhase': 0.27,
#      'temperatureHigh': 8.33,
#      'temperatureHighTime': 1042245360,
#      'temperatureLow': 4.26,
#      'temperatureLowTime': 1042286520,
#      'apparentTemperatureHigh': 6.23,
#      'apparentTemperatureHighTime': 1042244760,
#      'apparentTemperatureLow': 2.38,
#      'apparentTemperatureLowTime': 1042296120,
#      'dewPoint': 5.65,
#      'humidity': 0.94,
#      'windSpeed': 15.67,
#      'windGust': 45.49,
#      'windGustTime': 1042212600,
#      'windBearing': 234,
#      'uvIndex': 0,
#      'uvIndexTime': 1042185600,
#      'temperatureMin': 4.79,
#      'temperatureMinTime': 1042265880,
#      'temperatureMax': 8.33,
#      'temperatureMaxTime': 1042245360,
#      'apparentTemperatureMin': 2.26,
#      'apparentTemperatureMinTime': 1042196220,
#      'apparentTemperatureMax': 6.23,
#      'apparentTemperatureMaxTime': 1042244760}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 4.728,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 36.21302673657214,
#   'longitude': -120.35547481371893,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'sunriseTime': 1042211640,
#      'sunsetTime': 1042247160,
#      'moonPhase': 0.27,
#      'precipType': 'rain',
#      'temperatureHigh': 13.61,
#      'temperatureHighTime': 1042240440,
#      'temperatureLow': 8.9,
#      'temperatureLowTime': 1042264860,
#      'apparentTemperatureHigh': 13.33,
#      'apparentTemperatureHighTime': 1042240440,
#      'apparentTemperatureLow': 8.19,
#      'apparentTemperatureLowTime': 1042298160,
#      'dewPoint': 7.38,
#      'humidity': 0.76,
#      'pressure': 1019.7,
#      'windSpeed': 13.98,
#      'windGust': 41.72,
#      'windGustTime': 1042232460,
#      'windBearing': 206,
#      'cloudCover': 0.81,
#      'uvIndex': 2,
#      'uvIndexTime': 1042229460,
#      'visibility': 5.403,
#      'temperatureMin': 8.9,
#      'temperatureMinTime': 1042264860,
#      'temperatureMax': 13.61,
#      'temperatureMaxTime': 1042240440,
#      'apparentTemperatureMin': 8.71,
#      'apparentTemperatureMinTime': 1042264860,
#      'apparentTemperatureMax': 13.33,
#      'apparentTemperatureMaxTime': 1042240440}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 7.212,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 36.21302673657214,
#   'longitude': -120.06934123181935,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'sunriseTime': 1042211580,
#      'sunsetTime': 1042247100,
#      'moonPhase': 0.27,
#      'precipType': 'rain',
#      'temperatureHigh': 14.82,
#      'temperatureHighTime': 1042242000,
#      'temperatureLow': 5.5,
#      'temperatureLowTime': 1042286820,
#      'apparentTemperatureHigh': 14.54,
#      'apparentTemperatureHighTime': 1042242000,
#      'apparentTemperatureLow': 5.67,
#      'apparentTemperatureLowTime': 1042300560,
#      'dewPoint': 9.86,
#      'humidity': 0.86,
#      'pressure': 1019.4,
#      'windSpeed': 12.74,
#      'windGust': 43.43,
#      'windGustTime': 1042233120,
#      'windBearing': 150,
#      'cloudCover': 0.82,
#      'uvIndex': 2,
#      'uvIndexTime': 1042229580,
#      'visibility': 5.715,
#      'temperatureMin': 7.8,
#      'temperatureMinTime': 1042265220,
#      'temperatureMax': 14.82,
#      'temperatureMaxTime': 1042242000,
#      'apparentTemperatureMin': 6.92,
#      'apparentTemperatureMinTime': 1042265040,
#      'apparentTemperatureMax': 14.54,
#      'apparentTemperatureMaxTime': 1042242000}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 5.821,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 36.21302673657214,
#   'longitude': -119.78320764991977,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'sunriseTime': 1042211520,
#      'sunsetTime': 1042247040,
#      'moonPhase': 0.27,
#      'precipType': 'rain',
#      'temperatureHigh': 14.87,
#      'temperatureHighTime': 1042242540,
#      'temperatureLow': 3.76,
#      'temperatureLowTime': 1042292700,
#      'apparentTemperatureHigh': 14.59,
#      'apparentTemperatureHighTime': 1042242540,
#      'apparentTemperatureLow': 4.03,
#      'apparentTemperatureLowTime': 1042292700,
#      'dewPoint': 10.45,
#      'humidity': 0.93,
#      'pressure': 1019.5,
#      'windSpeed': 8.14,
#      'windGust': 46.65,
#      'windGustTime': 1042234320,
#      'windBearing': 127,
#      'cloudCover': 0.75,
#      'uvIndex': 2,
#      'uvIndexTime': 1042230000,
#      'visibility': 6.512,
#      'temperatureMin': 7.62,
#      'temperatureMinTime': 1042268400,
#      'temperatureMax': 14.87,
#      'temperatureMaxTime': 1042242540,
#      'apparentTemperatureMin': 7.13,
#      'apparentTemperatureMinTime': 1042265100,
#      'apparentTemperatureMax': 14.59,
#      'apparentTemperatureMaxTime': 1042242540}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 17.757,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 36.21302673657214,
#   'longitude': -119.4970740680202,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'sunriseTime': 1042211460,
#      'sunsetTime': 1042246980,
#      'moonPhase': 0.27,
#      'precipIntensity': 0.5447,
#      'precipIntensityMax': 1.0332,
#      'precipIntensityMaxTime': 1042224900,
#      'precipType': 'rain',
#      'temperatureHigh': 14.45,
#      'temperatureHighTime': 1042243200,
#      'temperatureLow': 3.85,
#      'temperatureLowTime': 1042299720,
#      'apparentTemperatureHigh': 14.17,
#      'apparentTemperatureHighTime': 1042243200,
#      'apparentTemperatureLow': 3.96,
#      'apparentTemperatureLowTime': 1042291140,
#      'dewPoint': 10.05,
#      'humidity': 0.94,
#      'pressure': 1019.5,
#      'windSpeed': 4.88,
#      'windBearing': 103,
#      'cloudCover': 0.66,
#      'uvIndex': 2,
#      'uvIndexTime': 1042229700,
#      'visibility': 8.18,
#      'temperatureMin': 7.27,
#      'temperatureMinTime': 1042268400,
#      'temperatureMax': 14.45,
#      'temperatureMaxTime': 1042243200,
#      'apparentTemperatureMin': 7.54,
#      'apparentTemperatureMinTime': 1042268400,
#      'apparentTemperatureMax': 14.17,
#      'apparentTemperatureMaxTime': 1042243200}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 12.395,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 36.427491337460225,
#   'longitude': -123.50294421461426,
#   'timezone': 'America/Los_Angeles',
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 36.427491337460225,
#   'longitude': -123.21681063271468,
#   'timezone': 'America/Los_Angeles',
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 79.784,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 36.427491337460225,
#   'longitude': -122.9306770508151,
#   'timezone': 'America/Los_Angeles',
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 58.046,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 36.427491337460225,
#   'longitude': -122.64454346891553,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'sunriseTime': 1042212240,
#      'sunsetTime': 1042247700,
#      'moonPhase': 0.27,
#      'temperatureHigh': 14,
#      'temperatureHighTime': 1042226580,
#      'temperatureLow': 12.23,
#      'temperatureLowTime': 1042300800,
#      'apparentTemperatureHigh': 13.72,
#      'apparentTemperatureHighTime': 1042226580,
#      'apparentTemperatureLow': 12.5,
#      'apparentTemperatureLowTime': 1042300800,
#      'pressure': 1016.7,
#      'windSpeed': 17.92,
#      'windBearing': 169,
#      'uvIndex': 0,
#      'uvIndexTime': 1042185600,
#      'temperatureMin': 12.63,
#      'temperatureMinTime': 1042236060,
#      'temperatureMax': 14,
#      'temperatureMaxTime': 1042226580,
#      'apparentTemperatureMin': 12.9,
#      'apparentTemperatureMinTime': 1042236060,
#      'apparentTemperatureMax': 13.72,
#      'apparentTemperatureMaxTime': 1042226580}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 41.043,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 36.427491337460225,
#   'longitude': -122.35840988701595,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'icon': 'rain',
#      'sunriseTime': 1042212180,
#      'sunsetTime': 1042247640,
#      'moonPhase': 0.27,
#      'precipIntensity': 0.7733,
#      'precipIntensityMax': 2.2014,
#      'precipIntensityMaxTime': 1042203660,
#      'precipProbability': 1,
#      'precipType': 'rain',
#      'temperatureHigh': 15.42,
#      'temperatureHighTime': 1042241640,
#      'temperatureLow': 11.15,
#      'temperatureLowTime': 1042300380,
#      'apparentTemperatureHigh': 15.14,
#      'apparentTemperatureHighTime': 1042241640,
#      'apparentTemperatureLow': 11.42,
#      'apparentTemperatureLowTime': 1042300380,
#      'dewPoint': 12.02,
#      'humidity': 0.9,
#      'pressure': 1017.3,
#      'windSpeed': 13.68,
#      'windBearing': 169,
#      'cloudCover': 0.75,
#      'uvIndex': 2,
#      'uvIndexTime': 1042231800,
#      'visibility': 14.038,
#      'temperatureMin': 12.26,
#      'temperatureMinTime': 1042268400,
#      'temperatureMax': 15.42,
#      'temperatureMaxTime': 1042241640,
#      'apparentTemperatureMin': 12.53,
#      'apparentTemperatureMinTime': 1042268400,
#      'apparentTemperatureMax': 15.14,
#      'apparentTemperatureMaxTime': 1042241640}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 36.21,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 36.427491337460225,
#   'longitude': -122.07227630511638,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'summary': 'Light rain in the morning.',
#      'icon': 'rain',
#      'sunriseTime': 1042212060,
#      'sunsetTime': 1042247520,
#      'moonPhase': 0.27,
#      'precipIntensity': 0.3795,
#      'precipIntensityMax': 2.4089,
#      'precipIntensityMaxTime': 1042203780,
#      'precipProbability': 1,
#      'precipType': 'rain',
#      'temperatureHigh': 17.22,
#      'temperatureHighTime': 1042239540,
#      'temperatureLow': 10,
#      'temperatureLowTime': 1042300680,
#      'apparentTemperatureHigh': 16.94,
#      'apparentTemperatureHighTime': 1042239540,
#      'apparentTemperatureLow': 10.27,
#      'apparentTemperatureLowTime': 1042300680,
#      'dewPoint': 11.53,
#      'humidity': 0.86,
#      'pressure': 1018.6,
#      'windSpeed': 7.82,
#      'windGust': 26.62,
#      'windGustTime': 1042218000,
#      'windBearing': 161,
#      'cloudCover': 0.76,
#      'uvIndex': 2,
#      'uvIndexTime': 1042231380,
#      'visibility': 13.81,
#      'temperatureMin': 11.6,
#      'temperatureMinTime': 1042268400,
#      'temperatureMax': 17.22,
#      'temperatureMaxTime': 1042239540,
#      'apparentTemperatureMin': 11.87,
#      'apparentTemperatureMinTime': 1042268400,
#      'apparentTemperatureMax': 16.94,
#      'apparentTemperatureMaxTime': 1042239540}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 16.658,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 36.427491337460225,
#   'longitude': -121.7861427232168,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'summary': 'Light rain in the morning.',
#      'icon': 'rain',
#      'sunriseTime': 1042212000,
#      'sunsetTime': 1042247460,
#      'moonPhase': 0.27,
#      'precipIntensity': 0.3867,
#      'precipIntensityMax': 2.4285,
#      'precipIntensityMaxTime': 1042203780,
#      'precipProbability': 1,
#      'precipType': 'rain',
#      'temperatureHigh': 14.21,
#      'temperatureHighTime': 1042240980,
#      'temperatureLow': 6.49,
#      'temperatureLowTime': 1042300740,
#      'apparentTemperatureHigh': 13.93,
#      'apparentTemperatureHighTime': 1042240980,
#      'apparentTemperatureLow': 5.98,
#      'apparentTemperatureLowTime': 1042276500,
#      'dewPoint': 10.25,
#      'humidity': 0.98,
#      'pressure': 1018.9,
#      'windSpeed': 6.51,
#      'windGust': 22.95,
#      'windGustTime': 1042218000,
#      'windBearing': 158,
#      'cloudCover': 0.77,
#      'uvIndex': 2,
#      'uvIndexTime': 1042231140,
#      'visibility': 13.726,
#      'temperatureMin': 8.19,
#      'temperatureMinTime': 1042268400,
#      'temperatureMax': 14.21,
#      'temperatureMaxTime': 1042240980,
#      'apparentTemperatureMin': 7.88,
#      'apparentTemperatureMinTime': 1042268400,
#      'apparentTemperatureMax': 13.93,
#      'apparentTemperatureMaxTime': 1042240980}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 9.75,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 36.427491337460225,
#   'longitude': -121.50000914131724,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'summary': 'Light rain in the morning.',
#      'icon': 'rain',
#      'sunriseTime': 1042211940,
#      'sunsetTime': 1042247400,
#      'moonPhase': 0.27,
#      'precipIntensity': 0.3955,
#      'precipIntensityMax': 2.0937,
#      'precipIntensityMaxTime': 1042205040,
#      'precipProbability': 1,
#      'precipType': 'rain',
#      'temperatureHigh': 12.95,
#      'temperatureHighTime': 1042242480,
#      'temperatureLow': 3.83,
#      'temperatureLowTime': 1042300560,
#      'apparentTemperatureHigh': 12.67,
#      'apparentTemperatureHighTime': 1042242480,
#      'apparentTemperatureLow': 2.75,
#      'apparentTemperatureLowTime': 1042296780,
#      'dewPoint': 8.51,
#      'humidity': 0.99,
#      'pressure': 1018.9,
#      'windSpeed': 5.55,
#      'windGust': 24.81,
#      'windGustTime': 1042225380,
#      'windBearing': 147,
#      'cloudCover': 0.8,
#      'uvIndex': 2,
#      'uvIndexTime': 1042228980,
#      'visibility': 13.379,
#      'temperatureMin': 6.09,
#      'temperatureMinTime': 1042268400,
#      'temperatureMax': 12.95,
#      'temperatureMaxTime': 1042242480,
#      'apparentTemperatureMin': 5.35,
#      'apparentTemperatureMinTime': 1042268400,
#      'apparentTemperatureMax': 12.67,
#      'apparentTemperatureMaxTime': 1042242480}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 2.067,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 36.427491337460225,
#   'longitude': -121.21387555941766,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'summary': 'Rain in the morning.',
#      'icon': 'rain',
#      'sunriseTime': 1042211880,
#      'sunsetTime': 1042247340,
#      'moonPhase': 0.27,
#      'precipIntensity': 0.4168,
#      'precipIntensityMax': 3.2367,
#      'precipIntensityMaxTime': 1042207140,
#      'precipProbability': 1,
#      'precipType': 'rain',
#      'temperatureHigh': 16.11,
#      'temperatureHighTime': 1042242780,
#      'temperatureLow': 4.68,
#      'temperatureLowTime': 1042300380,
#      'apparentTemperatureHigh': 15.83,
#      'apparentTemperatureHighTime': 1042242780,
#      'apparentTemperatureLow': 4.63,
#      'apparentTemperatureLowTime': 1042298760,
#      'dewPoint': 9.66,
#      'humidity': 0.89,
#      'pressure': 1018.8,
#      'windSpeed': 6.94,
#      'windGust': 32.41,
#      'windGustTime': 1042225560,
#      'windBearing': 152,
#      'cloudCover': 0.87,
#      'uvIndex': 2,
#      'uvIndexTime': 1042228800,
#      'visibility': 13.02,
#      'temperatureMin': 8.79,
#      'temperatureMinTime': 1042268400,
#      'temperatureMax': 16.11,
#      'temperatureMaxTime': 1042242780,
#      'apparentTemperatureMin': 8.99,
#      'apparentTemperatureMinTime': 1042261920,
#      'apparentTemperatureMax': 15.83,
#      'apparentTemperatureMaxTime': 1042242780}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 7.313,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 36.427491337460225,
#   'longitude': -120.92774197751808,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'sunriseTime': 1042211820,
#      'sunsetTime': 1042247280,
#      'moonPhase': 0.27,
#      'temperatureHigh': 11.29,
#      'temperatureHighTime': 1042243620,
#      'temperatureLow': 6.52,
#      'temperatureLowTime': 1042299780,
#      'apparentTemperatureHigh': 11.13,
#      'apparentTemperatureHighTime': 1042244160,
#      'apparentTemperatureLow': 5.73,
#      'apparentTemperatureLowTime': 1042299420,
#      'dewPoint': 6.86,
#      'humidity': 0.86,
#      'windSpeed': 15.56,
#      'windGust': 53.08,
#      'windGustTime': 1042210980,
#      'windBearing': 176,
#      'uvIndex': 0,
#      'uvIndexTime': 1042185600,
#      'temperatureMin': 7.66,
#      'temperatureMinTime': 1042268400,
#      'temperatureMax': 11.29,
#      'temperatureMaxTime': 1042243620,
#      'apparentTemperatureMin': 4.66,
#      'apparentTemperatureMinTime': 1042185600,
#      'apparentTemperatureMax': 11.13,
#      'apparentTemperatureMaxTime': 1042244160}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 3.776,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 36.427491337460225,
#   'longitude': -120.6416083956185,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'sunriseTime': 1042211760,
#      'sunsetTime': 1042247220,
#      'moonPhase': 0.27,
#      'temperatureHigh': 10.21,
#      'temperatureHighTime': 1042244940,
#      'temperatureLow': 7.48,
#      'temperatureLowTime': 1042290240,
#      'apparentTemperatureHigh': 8.32,
#      'apparentTemperatureHighTime': 1042243740,
#      'apparentTemperatureLow': 5.35,
#      'apparentTemperatureLowTime': 1042295400,
#      'dewPoint': 4.93,
#      'humidity': 0.76,
#      'windSpeed': 18.07,
#      'windGust': 51.53,
#      'windGustTime': 1042185600,
#      'windBearing': 240,
#      'uvIndex': 0,
#      'uvIndexTime': 1042185600,
#      'temperatureMin': 7.68,
#      'temperatureMinTime': 1042262400,
#      'temperatureMax': 10.21,
#      'temperatureMaxTime': 1042244940,
#      'apparentTemperatureMin': 5.05,
#      'apparentTemperatureMinTime': 1042218600,
#      'apparentTemperatureMax': 8.32,
#      'apparentTemperatureMaxTime': 1042243740}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 9.563,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 36.427491337460225,
#   'longitude': -120.35547481371893,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'sunriseTime': 1042211700,
#      'sunsetTime': 1042247160,
#      'moonPhase': 0.27,
#      'precipType': 'rain',
#      'temperatureHigh': 13.99,
#      'temperatureHighTime': 1042243020,
#      'temperatureLow': 9.94,
#      'temperatureLowTime': 1042297740,
#      'apparentTemperatureHigh': 13.71,
#      'apparentTemperatureHighTime': 1042243020,
#      'apparentTemperatureLow': 10.21,
#      'apparentTemperatureLowTime': 1042297740,
#      'dewPoint': 5.9,
#      'humidity': 0.66,
#      'pressure': 1019.7,
#      'windSpeed': 17.56,
#      'windGust': 51.91,
#      'windGustTime': 1042213320,
#      'windBearing': 229,
#      'cloudCover': 0.81,
#      'uvIndex': 2,
#      'uvIndexTime': 1042229460,
#      'visibility': 5.403,
#      'temperatureMin': 10.13,
#      'temperatureMinTime': 1042264440,
#      'temperatureMax': 13.99,
#      'temperatureMaxTime': 1042243020,
#      'apparentTemperatureMin': 10.4,
#      'apparentTemperatureMinTime': 1042264440,
#      'apparentTemperatureMax': 13.71,
#      'apparentTemperatureMaxTime': 1042243020}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 23.471,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 36.427491337460225,
#   'longitude': -120.06934123181935,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'sunriseTime': 1042211580,
#      'sunsetTime': 1042247040,
#      'moonPhase': 0.27,
#      'precipType': 'rain',
#      'temperatureHigh': 15.39,
#      'temperatureHighTime': 1042242660,
#      'temperatureLow': 5.59,
#      'temperatureLowTime': 1042286700,
#      'apparentTemperatureHigh': 15.11,
#      'apparentTemperatureHighTime': 1042242660,
#      'apparentTemperatureLow': 5.86,
#      'apparentTemperatureLowTime': 1042286700,
#      'dewPoint': 9.86,
#      'humidity': 0.87,
#      'pressure': 1019.3,
#      'windSpeed': 12.05,
#      'windGust': 48.81,
#      'windGustTime': 1042232760,
#      'windBearing': 140,
#      'cloudCover': 0.82,
#      'uvIndex': 2,
#      'uvIndexTime': 1042229520,
#      'visibility': 6.899,
#      'temperatureMin': 7.95,
#      'temperatureMinTime': 1042265100,
#      'temperatureMax': 15.39,
#      'temperatureMaxTime': 1042242660,
#      'apparentTemperatureMin': 6.99,
#      'apparentTemperatureMinTime': 1042264980,
#      'apparentTemperatureMax': 15.11,
#      'apparentTemperatureMaxTime': 1042242660}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 14.853,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 36.427491337460225,
#   'longitude': -119.78320764991977,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'summary': 'Light rain in the morning and afternoon.',
#      'icon': 'rain',
#      'sunriseTime': 1042211520,
#      'sunsetTime': 1042246980,
#      'moonPhase': 0.27,
#      'precipIntensity': 0.3126,
#      'precipIntensityMax': 1.4488,
#      'precipIntensityMaxTime': 1042224060,
#      'precipProbability': 1,
#      'precipType': 'rain',
#      'temperatureHigh': 14.96,
#      'temperatureHighTime': 1042242600,
#      'temperatureLow': 3.86,
#      'temperatureLowTime': 1042293300,
#      'apparentTemperatureHigh': 14.68,
#      'apparentTemperatureHighTime': 1042242600,
#      'apparentTemperatureLow': 4.13,
#      'apparentTemperatureLowTime': 1042293300,
#      'dewPoint': 10.43,
#      'humidity': 0.94,
#      'pressure': 1019.4,
#      'windSpeed': 7.39,
#      'windBearing': 114,
#      'cloudCover': 0.76,
#      'uvIndex': 2,
#      'uvIndexTime': 1042229760,
#      'visibility': 7.359,
#      'temperatureMin': 7.7,
#      'temperatureMinTime': 1042268400,
#      'temperatureMax': 14.96,
#      'temperatureMaxTime': 1042242600,
#      'apparentTemperatureMin': 7.54,
#      'apparentTemperatureMinTime': 1042265100,
#      'apparentTemperatureMax': 14.68,
#      'apparentTemperatureMaxTime': 1042242600}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 18.221,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 36.427491337460225,
#   'longitude': -119.4970740680202,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'summary': 'Light rain in the morning and afternoon.',
#      'icon': 'rain',
#      'sunriseTime': 1042211460,
#      'sunsetTime': 1042246920,
#      'moonPhase': 0.27,
#      'precipIntensity': 0.2483,
#      'precipIntensityMax': 1.1443,
#      'precipIntensityMaxTime': 1042224720,
#      'precipProbability': 1,
#      'precipType': 'rain',
#      'temperatureHigh': 14.37,
#      'temperatureHighTime': 1042243140,
#      'temperatureLow': 3.73,
#      'temperatureLowTime': 1042294140,
# ...
#      'windBearing': 196,
#      'uvIndex': 0,
#      'uvIndexTime': 1042185600,
#      'temperatureMin': 7.19,
#      'temperatureMinTime': 1042193460,
#      'temperatureMax': 12.57,
#      'temperatureMaxTime': 1042240020,
#      'apparentTemperatureMin': 7.39,
#      'apparentTemperatureMinTime': 1042264680,
#      'apparentTemperatureMax': 12.29,
#      'apparentTemperatureMaxTime': 1042240020}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 5.019,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 39.00106654811723,
#   'longitude': -122.07227630511638,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'icon': 'rain',
#      'sunriseTime': 1042212480,
#      'sunsetTime': 1042247160,
#      'moonPhase': 0.27,
#      'precipIntensity': 0.5905,
#      'precipIntensityMax': 2.7517,
#      'precipIntensityMaxTime': 1042186200,
#      'precipProbability': 1,
#      'precipType': 'rain',
#      'temperatureHigh': 13.55,
#      'temperatureHighTime': 1042239900,
#      'temperatureLow': 10.09,
#      'temperatureLowTime': 1042300800,
#      'apparentTemperatureHigh': 13.27,
#      'apparentTemperatureHighTime': 1042239900,
#      'apparentTemperatureLow': 10.36,
#      'apparentTemperatureLowTime': 1042300800,
#      'dewPoint': 8.82,
#      'humidity': 0.88,
#      'pressure': 1017.6,
#      'windSpeed': 8.33,
#      'windGust': 39.81,
#      'windGustTime': 1042243080,
#      'windBearing': 172,
#      'cloudCover': 0.99,
#      'uvIndex': 2,
#      'uvIndexTime': 1042229700,
#      'visibility': 9.784,
#      'temperatureMin': 8.4,
#      'temperatureMinTime': 1042194540,
#      'temperatureMax': 13.55,
#      'temperatureMaxTime': 1042239900,
#      'apparentTemperatureMin': 8.67,
#      'apparentTemperatureMinTime': 1042194540,
#      'apparentTemperatureMax': 13.27,
#      'apparentTemperatureMaxTime': 1042239900}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 8.142,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 39.00106654811723,
#   'longitude': -121.7861427232168,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'summary': 'Light rain throughout the day.',
#      'icon': 'rain',
#      'sunriseTime': 1042212420,
#      'sunsetTime': 1042247100,
#      'moonPhase': 0.27,
#      'precipIntensity': 0.4468,
#      'precipIntensityMax': 2.473,
#      'precipIntensityMaxTime': 1042185900,
#      'precipProbability': 1,
#      'precipType': 'rain',
#      'temperatureHigh': 13.8,
#      'temperatureHighTime': 1042239540,
#      'temperatureLow': 9.06,
#      'temperatureLowTime': 1042299600,
#      'apparentTemperatureHigh': 13.52,
#      'apparentTemperatureHighTime': 1042239540,
#      'apparentTemperatureLow': 9.33,
#      'apparentTemperatureLowTime': 1042299600,
#      'dewPoint': 10.51,
#      'humidity': 0.95,
#      'pressure': 1017.5,
#      'windSpeed': 12.96,
#      'windGust': 34.6,
#      'windGustTime': 1042242360,
#      'windBearing': 152,
#      'cloudCover': 0.99,
#      'uvIndex': 2,
#      'uvIndexTime': 1042229640,
#      'visibility': 9.659,
#      'temperatureMin': 8.25,
#      'temperatureMinTime': 1042197180,
#      'temperatureMax': 13.8,
#      'temperatureMaxTime': 1042239540,
#      'apparentTemperatureMin': 8.23,
#      'apparentTemperatureMinTime': 1042185600,
#      'apparentTemperatureMax': 13.52,
#      'apparentTemperatureMaxTime': 1042239540}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 21.92,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 39.00106654811723,
#   'longitude': -121.50000914131724,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'summary': 'Light rain throughout the day.',
#      'icon': 'rain',
#      'sunriseTime': 1042212360,
#      'sunsetTime': 1042246980,
#      'moonPhase': 0.27,
#      'precipIntensity': 0.4236,
#      'precipIntensityMax': 2.419,
#      'precipIntensityMaxTime': 1042186020,
#      'precipProbability': 1,
#      'precipType': 'rain',
#      'temperatureHigh': 13.94,
#      'temperatureHighTime': 1042239480,
#      'temperatureLow': 8.86,
#      'temperatureLowTime': 1042299060,
#      'apparentTemperatureHigh': 13.66,
#      'apparentTemperatureHighTime': 1042239480,
#      'apparentTemperatureLow': 9.13,
#      'apparentTemperatureLowTime': 1042299060,
#      'dewPoint': 10.26,
#      'humidity': 0.92,
#      'pressure': 1017.6,
#      'windSpeed': 12.18,
#      'windGust': 32.29,
#      'windGustTime': 1042240860,
#      'windBearing': 150,
#      'cloudCover': 0.99,
#      'uvIndex': 2,
#      'uvIndexTime': 1042229520,
#      'visibility': 9.536,
#      'temperatureMin': 8.9,
#      'temperatureMinTime': 1042197420,
#      'temperatureMax': 13.94,
#      'temperatureMaxTime': 1042239480,
#      'apparentTemperatureMin': 8.54,
#      'apparentTemperatureMinTime': 1042185600,
#      'apparentTemperatureMax': 13.66,
#      'apparentTemperatureMaxTime': 1042239480}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 10.463,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 39.00106654811723,
#   'longitude': -121.21387555941766,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'summary': 'Light rain throughout the day.',
#      'icon': 'rain',
#      'sunriseTime': 1042212300,
#      'sunsetTime': 1042246920,
#      'moonPhase': 0.27,
#      'precipIntensity': 0.1942,
#      'precipIntensityMax': 0.8465,
#      'precipIntensityMaxTime': 1042185660,
#      'precipProbability': 1,
#      'precipType': 'rain',
#      'temperatureHigh': 13.12,
#      'temperatureHighTime': 1042238520,
#      'temperatureLow': 8.37,
#      'temperatureLowTime': 1042299480,
#      'apparentTemperatureHigh': 12.84,
#      'apparentTemperatureHighTime': 1042238520,
#      'apparentTemperatureLow': 8.3,
#      'apparentTemperatureLowTime': 1042297020,
#      'dewPoint': 9.1,
#      'humidity': 0.89,
#      'pressure': 1017.5,
#      'windSpeed': 10.2,
#      'windGust': 28.27,
#      'windGustTime': 1042239720,
#      'windBearing': 147,
#      'cloudCover': 0.97,
#      'uvIndex': 2,
#      'uvIndexTime': 1042229340,
#      'visibility': 11.5,
#      'temperatureMin': 9.07,
#      'temperatureMinTime': 1042191900,
#      'temperatureMax': 13.12,
#      'temperatureMaxTime': 1042238520,
#      'apparentTemperatureMin': 8.52,
#      'apparentTemperatureMinTime': 1042185600,
#      'apparentTemperatureMax': 12.84,
#      'apparentTemperatureMaxTime': 1042238520}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 7.118,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 39.00106654811723,
#   'longitude': -120.92774197751808,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'summary': 'Light rain throughout the day.',
#      'icon': 'rain',
#      'sunriseTime': 1042212240,
#      'sunsetTime': 1042246860,
#      'moonPhase': 0.27,
#      'precipIntensity': 0.24,
#      'precipIntensityMax': 0.9848,
#      'precipIntensityMaxTime': 1042247040,
#      'precipProbability': 1,
#      'precipType': 'rain',
#      'temperatureHigh': 10.4,
#      'temperatureHighTime': 1042236780,
#      'temperatureLow': 6.49,
#      'temperatureLowTime': 1042300380,
#      'apparentTemperatureHigh': 10.1,
#      'apparentTemperatureHighTime': 1042236000,
#      'apparentTemperatureLow': 6.76,
#      'apparentTemperatureLowTime': 1042300500,
#      'dewPoint': 6.98,
#      'humidity': 0.89,
#      'pressure': 1017.3,
#      'windSpeed': 9.9,
#      'windGust': 27.69,
#      'windGustTime': 1042239840,
#      'windBearing': 150,
#      'cloudCover': 0.97,
#      'uvIndex': 2,
#      'uvIndexTime': 1042229220,
#      'visibility': 10.724,
#      'temperatureMin': 7.19,
#      'temperatureMinTime': 1042189020,
#      'temperatureMax': 10.4,
#      'temperatureMaxTime': 1042236780,
#      'apparentTemperatureMin': 6.17,
#      'apparentTemperatureMinTime': 1042189200,
#      'apparentTemperatureMax': 10.1,
#      'apparentTemperatureMaxTime': 1042236000}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 5.389,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 39.00106654811723,
#   'longitude': -120.6416083956185,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'summary': 'Light rain throughout the day.',
#      'icon': 'rain',
#      'sunriseTime': 1042212120,
#      'sunsetTime': 1042246800,
#      'moonPhase': 0.27,
#      'precipIntensity': 0.5465,
#      'precipIntensityMax': 1.8516,
#      'precipIntensityMaxTime': 1042250100,
#      'precipProbability': 1,
#      'precipType': 'rain',
#      'temperatureHigh': 5.89,
#      'temperatureHighTime': 1042238580,
#      'temperatureLow': 2.92,
#      'temperatureLowTime': 1042300800,
#      'apparentTemperatureHigh': 4.59,
#      'apparentTemperatureHighTime': 1042232520,
#      'apparentTemperatureLow': 2.72,
#      'apparentTemperatureLowTime': 1042257300,
#      'dewPoint': 3.73,
#      'humidity': 0.92,
#      'pressure': 1017.3,
#      'windSpeed': 7.9,
#      'windGust': 31.07,
#      'windGustTime': 1042189860,
#      'windBearing': 176,
#      'cloudCover': 0.99,
#      'uvIndex': 2,
#      'uvIndexTime': 1042229280,
#      'visibility': 5.851,
#      'temperatureMin': 3.55,
#      'temperatureMinTime': 1042186500,
#      'temperatureMax': 6.01,
#      'temperatureMaxTime': 1042265040,
#      'apparentTemperatureMin': 1.62,
#      'apparentTemperatureMinTime': 1042189260,
#      'apparentTemperatureMax': 4.59,
#      'apparentTemperatureMaxTime': 1042232520}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 8.071,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 39.00106654811723,
#   'longitude': -120.35547481371893,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'summary': 'Snow (3–9 cm.) until morning, starting again in the evening.',
#      'icon': 'snow',
#      'sunriseTime': 1042212060,
#      'sunsetTime': 1042246740,
#      'moonPhase': 0.27,
#      'precipIntensity': 0.3333,
#      'precipIntensityMax': 1.1331,
#      'precipIntensityMaxTime': 1042250280,
#      'precipProbability': 1,
#      'precipType': 'snow',
#      'precipAccumulation': 4.4,
#      'temperatureHigh': 2.1,
#      'temperatureHighTime': 1042233000,
#      'temperatureLow': -2.21,
#      'temperatureLowTime': 1042300260,
#      'apparentTemperatureHigh': 1.8,
#      'apparentTemperatureHighTime': 1042232520,
#      'apparentTemperatureLow': -3.73,
#      'apparentTemperatureLowTime': 1042300800,
#      'dewPoint': 0.6,
#      'humidity': 1,
#      'pressure': 1016.5,
#      'windSpeed': 6.32,
#      'windGust': 26.74,
#      'windGustTime': 1042264080,
#      'windBearing': 224,
#      'cloudCover': 0.97,
#      'uvIndex': 2,
#      'uvIndexTime': 1042229940,
#      'visibility': 9.356,
#      'temperatureMin': -0.52,
#      'temperatureMinTime': 1042214220,
#      'temperatureMax': 2.1,
#      'temperatureMaxTime': 1042233000,
#      'apparentTemperatureMin': -2.67,
#      'apparentTemperatureMinTime': 1042189140,
#      'apparentTemperatureMax': 1.8,
#      'apparentTemperatureMaxTime': 1042232520}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 9.443,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 39.00106654811723,
#   'longitude': -120.06934123181935,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'summary': 'Overcast throughout the day.',
#      'icon': 'cloudy',
#      'sunriseTime': 1042212000,
#      'sunsetTime': 1042246680,
#      'moonPhase': 0.27,
#      'precipIntensity': 0.0079,
#      'precipIntensityMax': 0.0717,
#      'precipIntensityMaxTime': 1042257360,
#      'precipProbability': 0.12,
#      'precipType': 'snow',
#      'precipAccumulation': 0.1,
#      'temperatureHigh': 3.77,
#      'temperatureHighTime': 1042233300,
#      'temperatureLow': -2.84,
#      'temperatureLowTime': 1042300020,
#      'apparentTemperatureHigh': 2.23,
#      'apparentTemperatureHighTime': 1042232640,
#      'apparentTemperatureLow': -2.57,
#      'apparentTemperatureLowTime': 1042300020,
#      'dewPoint': 0.26,
#      'humidity': 0.9,
#      'pressure': 1016.1,
#      'windSpeed': 4.95,
#      'windGust': 24.88,
#      'windGustTime': 1042261560,
#      'windBearing': 189,
#      'cloudCover': 0.96,
#      'uvIndex': 2,
#      'uvIndexTime': 1042230540,
#      'visibility': 12.863,
#      'temperatureMin': 0.37,
#      'temperatureMinTime': 1042205460,
#      'temperatureMax': 3.77,
#      'temperatureMaxTime': 1042233300,
#      'apparentTemperatureMin': -1.53,
#      'apparentTemperatureMinTime': 1042264200,
#      'apparentTemperatureMax': 2.23,
#      'apparentTemperatureMaxTime': 1042232640}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 3.895,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 39.00106654811723,
#   'longitude': -119.78320764991977,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'summary': 'Overcast throughout the day.',
#      'icon': 'cloudy',
#      'sunriseTime': 1042211940,
#      'sunsetTime': 1042246620,
#      'moonPhase': 0.27,
#      'precipIntensity': 0.0117,
#      'precipIntensityMax': 0.1063,
#      'precipIntensityMaxTime': 1042257360,
#      'precipProbability': 0.18,
#      'precipType': 'rain',
#      'temperatureHigh': 6.71,
#      'temperatureHighTime': 1042237440,
#      'temperatureLow': -0.25,
#      'temperatureLowTime': 1042300020,
#      'apparentTemperatureHigh': 6.38,
#      'apparentTemperatureHighTime': 1042236240,
#      'apparentTemperatureLow': 0.02,
#      'apparentTemperatureLowTime': 1042300020,
#      'dewPoint': 0.52,
#      'humidity': 0.78,
#      'pressure': 1016.1,
#      'windSpeed': 4.61,
#      'windGust': 25.34,
#      'windGustTime': 1042261860,
#      'windBearing': 191,
#      'cloudCover': 0.96,
#      'uvIndex': 2,
#      'uvIndexTime': 1042230420,
#      'visibility': 12.726,
#      'temperatureMin': 2.09,
#      'temperatureMinTime': 1042206060,
#      'temperatureMax': 6.71,
#      'temperatureMaxTime': 1042237440,
#      'apparentTemperatureMin': 1.89,
#      'apparentTemperatureMinTime': 1042261740,
#      'apparentTemperatureMax': 6.38,
#      'apparentTemperatureMaxTime': 1042236240}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 0.347,
#    'units': 'ca'},
#   'offset': -8},
#  {'latitude': 39.00106654811723,
#   'longitude': -119.4970740680202,
#   'timezone': 'America/Los_Angeles',
#   'daily': {'data': [{'time': 1042185600,
#      'summary': 'Overcast throughout the day.',
#      'icon': 'cloudy',
#      'sunriseTime': 1042211880,
#      'sunsetTime': 1042246500,
#      'moonPhase': 0.27,
#      'precipIntensity': 0,
#      'precipIntensityMax': 0,
#      'precipProbability': 0,
#      'temperatureHigh': 3.37,
#      'temperatureHighTime': 1042240740,
#      'temperatureLow': -3.53,
#      'temperatureLowTime': 1042300320,
#      'apparentTemperatureHigh': 2.85,
#      'apparentTemperatureHighTime': 1042236120,
#      'apparentTemperatureLow': -3.96,
#      'apparentTemperatureLowTime': 1042293540,
#      'dewPoint': -0.19,
#      'humidity': 0.97,
#      'pressure': 1016.1,
#      'windSpeed': 4.99,
#      'windGust': 28.1,
#      'windGustTime': 1042261740,
#      'windBearing': 190,
#      'cloudCover': 0.95,
#      'uvIndex': 2,
#      'uvIndexTime': 1042230600,
#      'visibility': 13.083,
#      'temperatureMin': -1.93,
#      'temperatureMinTime': 1042201620,
#      'temperatureMax': 3.37,
#      'temperatureMaxTime': 1042240740,
#      'apparentTemperatureMin': -3.06,
#      'apparentTemperatureMinTime': 1042261200,
#      'apparentTemperatureMax': 2.85,
#      'apparentTemperatureMaxTime': 1042236120}]},
#   'flags': {'sources': ['cmc',
#     'gfs',
#     'hrrr',
#     'icon',
#     'isd',
#     'madis',
#     'nam',
#     'sref'],
#    'nearest-station': 10.309,
#    'units': 'ca'},
#   'offset': -8}]
